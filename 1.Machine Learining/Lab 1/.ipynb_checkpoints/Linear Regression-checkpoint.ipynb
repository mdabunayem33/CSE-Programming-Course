# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in d:\software\new folder\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in d:\software\new folder\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in d:\software\new folder\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in d:\software\new folder\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in d:\software\new folder\lib\site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\new folder\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\new folder\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\new folder\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\software\new folder\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\software\new folder\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software\new folder\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\software\new folder\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\software\new folder\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\software\new folder\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\software\new folder\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in d:\software\new folder\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\software\new folder\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\software\new folder\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in d:\software\new folder\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
random_state = 270
np.random.seed(random_state)

# %%
df = pd.read_csv('USA_housing_toy.csv')
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              2500 non-null   float64
#  1   Avg. Area House Age           2500 non-null   float64
#  2   Avg. Area Number of Rooms     2500 non-null   float64
#  3   Avg. Area Number of Bedrooms  2500 non-null   float64
#  4   Area Population               2500 non-null   float64
#  5   Price                         2500 non-null   float64
#  6   Address                       2500 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 136.8+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       2500.000000          2500.000000                2500.000000
# mean       68593.117818             5.980941                   7.005079
# std        10696.969146             1.007664                   1.002411
# min        17796.631190             2.644304                   3.236194
# 25%        61461.357480             5.328918                   6.311252
# 50%        68709.189825             5.981525                   7.024682
# 75%        75868.888025             6.680616                   7.687694
# max       107701.748400             8.991399                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   2500.000000      2500.000000  2.500000e+03
# mean                       3.989816     36032.881352  1.233117e+06
# std                        1.241848      9803.908974  3.547254e+05
# min                        2.000000       172.610686  3.114052e+04
# 25%                        3.150000     29381.948903  9.937032e+05
# 50%                        4.050000     36073.859200  1.235056e+06
# 75%                        4.500000     42683.564510  1.467923e+06
# max                        6.500000     69592.040240  2.469066e+06

# %%
x = df[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=random_state)

# %%
print(f"x_train:{x_train.shape}")
print(f"x_test:{x_test.shape}")
print(f"y_train:{y_train.shape}")
print(f"y_test:{y_test.shape}")
# Out:
# x_train:(1500, 5)
# x_test:(1000, 5)
# y_train:(1500,)
# y_test:(1000,)

# %%
x_train[0:5]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1278       61478.63393             4.269446                   6.231330
# 1866       68450.26242             5.474151                   7.376390
# 663        55554.79675             5.849591                   7.753370
# 1147       69577.13762             6.019581                   8.103830
# 917        63759.05070             6.135727                   7.614218
#
#       Avg. Area Number of Bedrooms  Area Population
# 1278                          4.26      36837.81793
# 1866                          4.08      36474.39183
# 663                           5.03      44903.44532
# 1147                          5.05      48122.10195
# 917                           6.23      35071.99599

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("intercept:",model.intercept_)
# Out:
# intercept: 1234067.4108197466

# %%
coeff_df = pd.DataFrame(model.coef_,x.columns,columns=['coefficient'])
coeff_df
# Out:
#                                 coefficient
# Avg. Area Income              229717.993146
# Avg. Area House Age           164946.113552
# Avg. Area Number of Rooms     118669.430772
# Avg. Area Number of Bedrooms    -476.024353
# Area Population               149292.872165

# %%
predictions = model.predict(x_test)
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions,s=20,facecolors='none',edgecolor='blue')
plt.xlabel("True prices  (y_test)")
plt.ylabel("predicted prices (predictions)")
plt.title("true prices vs.predicted prices")
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],'r--',label='zero Error Line')
plt.legend()
plt.show()

# %%
from sklearn import metrics
print('MAE      :',metrics.mean_abso
